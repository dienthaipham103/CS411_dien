# %% [markdown]
# ### Plot the graph of a function y = sin(2$\pi$x + $\pi$/6)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 100 linearly spaced numbers
x = np.linspace(-4, 4, 200)
# x

# %%
y = np.sin(x*np.pi + np.pi/6)
# y

# %%
fig, ax = plt.subplots()

# plot the function
ax.plot(x,y, color='r')
ax.grid()

# add labels
ax.set_xlabel("x")
ax.set_ylabel("y")

# show the plot
plt.show()

# %% [markdown]
# ### Plot the graph of a function y = 3x<sup>2</sup> + 1 with 100 points (The points are generated randomly based on normal distribution)

# %%
# 100 linearly spaced numbers with normal distribution ()
x = np.random.normal(1,10,100)
print(np.mean(x))
print(np.std(x))
# print(x)
# Out:
# 1.813492360533165
# 9.450528876227374

# %%
y = 3*x**2 + 1
# print(y)

# %%
fig, ax = plt.subplots()

# plot the function
ax.scatter(x,y, color='r')
ax.grid()

# add labels
ax.set_xlabel("x")
ax.set_ylabel("y")

# show the plot
plt.show()
